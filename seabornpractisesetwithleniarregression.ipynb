# %%
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv("Advertising.csv")

data.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %% [markdown]
# ## Step 1 : Understanding the business case and domain analysis
# ## Step2 : Bais checks and EDA

# %%
data['TV'].sum()
# Out:
# 29408.5

# %%
data['Radio'].sum()
# Out:
# 4652.800000000001

# %%
data['Newspaper'].sum()
# Out:
# 6110.799999999999

# %%
data.shape
# Out:
# (200, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %% [markdown]
# # Univariate Analysis
#
#
# -- sibgle variable analysis
#
# # bivariate
#
# -- multiple variable analysis

# %%
import warnings
warnings.filterwarnings("ignore")

sns.distplot(x=data['TV'])
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ### - more like uniform distribution

# %%
sns.distplot(x=data['Radio'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x=data['Newspaper'])
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# # Bivariate analysis

# %%
sns.scatterplot(x="TV",y="Sales",data=data)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(x="Radio",y="Sales",data=data)

## high randomness
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(x="Newspaper",y="Sales",data=data)

## zero correlation with sales
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
### Multivariate Analysis

sns.pairplot(data=data)
